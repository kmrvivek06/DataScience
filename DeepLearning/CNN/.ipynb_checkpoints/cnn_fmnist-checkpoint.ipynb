# %%
#Import packages
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout
from tensorflow.keras.models import Model
from sklearn.metrics import confusion_matrix
import itertools

# %%
# Load data
fashion_mnist = tf.keras.datasets.fashion_mnist
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
X_train, X_test = X_train / 255.0, X_test/255.0

# %%
print('X_train shape', X_train.shape)
# Out:
# X_train shape (60000, 28, 28)

# %%
# expand dimentions as conv expects 3d data
X_train = np.expand_dims(X_train, -1)
X_test = np.expand_dims(X_test, -1)

# %%
print('X_train shape', X_train.shape)
# Out:
# X_train shape (60000, 28, 28, 1)

# %%
# Number of classes
K = len(set(y_train))
print('No. of classes',K)
# Out:
# No. of classes 10

# %%
# Build model (Functional API)
i = Input(shape=X_train[0].shape)
x = Conv2D(32, (3,3), strides=1, activation='relu')(i)
x = Conv2D(64, (3,3), strides=1, activation='relu')(x)
x = Conv2D(128, (3,3), strides=1, activation='relu')(x)
x = Flatten()(x)
x = Dropout(0.2)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(K, activation='softmax')(x)

model = Model(i,x)

# %%
# Compile and fit
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
r = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=15)
# Out:
# Epoch 1/15
# 1875/1875 [==============================] - 34s 18ms/step - loss: 0.3678 - accuracy: 0.8651 - val_loss: 0.2707 - val_accuracy: 0.9019
# Epoch 2/15
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.2269 - accuracy: 0.9162 - val_loss: 0.2386 - val_accuracy: 0.9138
# Epoch 3/15
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.1627 - accuracy: 0.9395 - val_loss: 0.2532 - val_accuracy: 0.9145
# Epoch 4/15
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.1112 - accuracy: 0.9596 - val_loss: 0.2839 - val_accuracy: 0.9128
# Epoch 5/15
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0763 - accuracy: 0.9723 - val_loss: 0.2932 - val_accuracy: 0.9221
# Epoch 6/15
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0501 - accuracy: 0.9818 - val_loss: 0.3415 - val_accuracy: 0.9230
# Epoch 7/15
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0430 - accuracy: 0.9854 - val_loss: 0.3498 - val_accuracy: 0.9208
# Epoch 8/15
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0332 - accuracy: 0.9888 - val_loss: 0.4271 - val_accuracy: 0.9207
# Epoch 9/15
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0294 - accuracy: 0.9900 - val_loss: 0.5275 - val_accuracy: 0.9164
# Epoch 10/15
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0286 - accuracy: 0.9908 - val_loss: 0.5004 - val_accuracy: 0.9210
# Epoch 11/15
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0260 - accuracy: 0.9916 - val_loss: 0.5049 - val_accuracy: 0.9166
# Epoch 12/15
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0239 - accuracy: 0.9926 - val_loss: 0.6099 - val_accuracy: 0.9162
# Epoch 13/15
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0231 - accuracy: 0.9927 - val_loss: 0.5544 - val_accuracy: 0.9225
# Epoch 14/15
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0226 - accuracy: 0.9932 - val_loss: 0.5847 - val_accuracy: 0.9187
# Epoch 15/15
# 1875/1875 [==============================] - 33s 18ms/step - loss: 0.0173 - accuracy: 0.9946 - val_loss: 0.6843 - val_accuracy: 0.9149

# %%
# Plot loss graph
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()
plt.show()

# %%
# Plot accuracy graph
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()
plt.show()

# %%
print(model.evaluate(X_test, y_test))
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6843 - accuracy: 0.9149
# [0.6842641830444336, 0.914900004863739]

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion Matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:,np.newaxis]
        print('Normalized confusion matrix')
    else:
        print('Confusion matrix without normalization')
        
    print(cm)
    
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i,j], fmt), horizontalalignment='center', color='white' if cm[i,j] > thresh else 'black')
        
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
p_test = model.predict(X_test).argmax(axis=1)
cm = confusion_matrix(y_test, p_test)
plot_confusion_matrix(cm, list(range(10)))
# Out:
# Confusion matrix without normalization
# [[839   2  17  13   1   0 121   0   7   0]
#  [  1 977   0  13   4   0   2   0   3   0]
#  [ 16   1 873   8  45   0  55   0   2   0]
#  [ 17   4   7 910  32   0  26   1   2   1]
#  [  1   0  44  31 849   0  74   0   1   0]
#  [  0   0   0   0   0 985   0   7   0   8]
#  [ 71   1  46  22  45   0 802   0  13   0]
#  [  0   0   0   0   0   9   1 966   0  24]
#  [  1   1   1   5   3   1   1   2 985   0]
#  [  0   0   1   0   0   7   0  29   0 963]]

# %%
misclassified_idx = np.where(p_test != y_test)[0]
i = np.random.choice(misclassified_idx)
plt.imshow(np.squeeze(X_test)[i], cmap='gray')
plt.title('True label : %s Predicted : %s' % (y_test[i], p_test[i]))
plt.show()
