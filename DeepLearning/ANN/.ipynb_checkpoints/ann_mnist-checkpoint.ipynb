# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.2.0

# %%
# Load dataset
mnist = tf.keras.datasets.mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train, X_test = X_train/255.0, X_test/255.0
print("X_train shape", X_train.shape)
# Out:
# X_train shape (60000, 28, 28)

# %%
# Build model
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
])

# %%
# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics='accuracy')

# %%
r = model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2985 - accuracy: 0.9136 - val_loss: 0.1377 - val_accuracy: 0.9598
# Epoch 2/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1439 - accuracy: 0.9574 - val_loss: 0.0980 - val_accuracy: 0.9695
# Epoch 3/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1047 - accuracy: 0.9682 - val_loss: 0.0821 - val_accuracy: 0.9751
# Epoch 4/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0884 - accuracy: 0.9734 - val_loss: 0.0773 - val_accuracy: 0.9756
# Epoch 5/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0742 - accuracy: 0.9767 - val_loss: 0.0747 - val_accuracy: 0.9772
# Epoch 6/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0664 - accuracy: 0.9796 - val_loss: 0.0761 - val_accuracy: 0.9767
# Epoch 7/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0584 - accuracy: 0.9809 - val_loss: 0.0642 - val_accuracy: 0.9797
# Epoch 8/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0514 - accuracy: 0.9836 - val_loss: 0.0698 - val_accuracy: 0.9789
# Epoch 9/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0487 - accuracy: 0.9845 - val_loss: 0.0659 - val_accuracy: 0.9803
# Epoch 10/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0432 - accuracy: 0.9857 - val_loss: 0.0696 - val_accuracy: 0.9812

# %%
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()
plt.show()

# %%
plt.plot(r.history['accuracy'], label='accuracy')
plt.plot(r.history['val_accuracy'], label='val_accuracy')
plt.legend()
plt.show()

# %%
print(model.evaluate(X_test, y_test))
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0696 - accuracy: 0.9812
# [0.06960530579090118, 0.9811999797821045]

# %%
# Plot confusion matrix
from sklearn.metrics import confusion_matrix
import numpy as np
import itertools

# %%
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion Matrix', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:,np.newaxis]
        print('Normalized confusion matrix')
    else:
        print('Confusion matrix without normalization')
        
    print(cm)
    
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i,j], fmt), horizontalalignment='center', color='white' if cm[i,j] > thresh else 'black')
        
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
p_test = model.predict(X_test).argmax(axis=1)
cm = confusion_matrix(y_test, p_test)
plot_confusion_matrix(cm, list(range(10)))
# Out:
# Confusion matrix without normalization
# [[ 969    0    1    1    1    1    2    1    3    1]
#  [   0 1127    4    0    0    0    1    0    3    0]
#  [   2    2 1014    0    2    0    2    5    4    1]
#  [   0    0    4  992    0    4    0    3    4    3]
#  [   0    0    2    0  966    0    4    1    0    9]
#  [   2    0    0   11    1  869    1    1    3    4]
#  [   4    3    3    1    4    4  936    0    3    0]
#  [   1    5   10    1    1    1    0  997    2   10]
#  [   4    0    1    3    5    1    1    3  952    4]
#  [   3    2    0    2    7    1    0    3    1  990]]

# %%
misclassified_idx = np.where(p_test != y_test)[0]
i = np.random.choice(misclassified_idx)
plt.imshow(X_test[i], cmap='gray')
plt.title('True label : %s Predicted : %s' % (y_test[i], p_test[i]))
plt.show()
