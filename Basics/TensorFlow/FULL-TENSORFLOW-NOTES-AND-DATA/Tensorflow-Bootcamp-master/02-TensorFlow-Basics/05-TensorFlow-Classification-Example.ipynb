# %% [markdown]
# # TensorFlow Classification

# %% [markdown]
# ## Data
#
# https://archive.ics.uci.edu/ml/datasets/pima+indians+diabetes
#
# 1. Title: Pima Indians Diabetes Database
#
# 2. Sources:
#    (a) Original owners: National Institute of Diabetes and Digestive and
#                         Kidney Diseases
#    (b) Donor of database: Vincent Sigillito (vgs@aplcen.apl.jhu.edu)
#                           Research Center, RMI Group Leader
#                           Applied Physics Laboratory
#                           The Johns Hopkins University
#                           Johns Hopkins Road
#                           Laurel, MD 20707
#                           (301) 953-6231
#    (c) Date received: 9 May 1990
#
# 3. Past Usage:
#     1. Smith,~J.~W., Everhart,~J.~E., Dickson,~W.~C., Knowler,~W.~C., \&
#        Johannes,~R.~S. (1988). Using the ADAP learning algorithm to forecast
#        the onset of diabetes mellitus.  In {\it Proceedings of the Symposium
#        on Computer Applications and Medical Care} (pp. 261--265).  IEEE
#        Computer Society Press.
#
#        The diagnostic, binary-valued variable investigated is whether the
#        patient shows signs of diabetes according to World Health Organization
#        criteria (i.e., if the 2 hour post-load plasma glucose was at least
#        200 mg/dl at any survey  examination or if found during routine medical
#        care).   The population lives near Phoenix, Arizona, USA.
#
#        Results: Their ADAP algorithm makes a real-valued prediction between
#        0 and 1.  This was transformed into a binary decision using a cutoff of
#        0.448.  Using 576 training instances, the sensitivity and specificity
#        of their algorithm was 76% on the remaining 192 instances.
#
# 4. Relevant Information:
#       Several constraints were placed on the selection of these instances from
#       a larger database.  In particular, all patients here are females at
#       least 21 years old of Pima Indian heritage.  ADAP is an adaptive learning
#       routine that generates and executes digital analogs of perceptron-like
#       devices.  It is a unique algorithm; see the paper for details.
#
# 5. Number of Instances: 768
#
# 6. Number of Attributes: 8 plus class
#
#     7. For Each Attribute: (all numeric-valued)
#        1. Number of times pregnant
#        2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#        3. Diastolic blood pressure (mm Hg)
#        4. Triceps skin fold thickness (mm)
#        5. 2-Hour serum insulin (mu U/ml)
#        6. Body mass index (weight in kg/(height in m)^2)
#        7. Diabetes pedigree function
#        8. Age (years)
#        9. Class variable (0 or 1)
#
# 8. Missing Attribute Values: Yes
#
# 9. Class Distribution: (class value 1 is interpreted as "tested positive for
#    diabetes")
#
#    Class Value  Number of instances
#    0            500
#    1            268
#
# 10. Brief statistical analysis:
#
#         Attribute number:    Mean:   Standard Deviation:
#         1.                     3.8     3.4
#         2.                   120.9    32.0
#         3.                    69.1    19.4
#         4.                    20.5    16.0
#         5.                    79.8   115.2
#         6.                    32.0     7.9
#         7.                     0.5     0.3
#         8.                    33.2    11.8

# %%
import pandas as pd

# %%
diabetes = pd.read_csv('pima-indians-diabetes.csv')

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %% [markdown]
# ### Clean the Data

# %%
cols_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min()))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %% [markdown]
# ### Feature Columns

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
import tensorflow as tf

# %% [markdown]
# ### Continuous Features
#
# * Number of times pregnant
# * Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# * Diastolic blood pressure (mm Hg)
# * Triceps skin fold thickness (mm)
# * 2-Hour serum insulin (mu U/ml)
# * Body mass index (weight in kg/(height in m)^2)
# * Diabetes pedigree function

# %%
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %% [markdown]
# ### Categorical Features

# %% [markdown]
# If you know the set of all possible feature values of a column and there are only a few of them, you can use categorical_column_with_vocabulary_list. If you don't know the set of possible values in advance you can use categorical_column_with_hash_bucket

# %%
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A','B','C','D'])
# Alternative
# assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group', hash_bucket_size=10)

# %% [markdown]
# ### Converting Continuous to Categorical

# %%
assigned_group
# Out:
# _VocabularyListCategoricalColumn(key='Group', vocabulary_list=('A', 'B', 'C', 'D'), dtype=tf.string, default_value=-1, num_oov_buckets=0)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes['Age'].hist(bins=20)

# %%
age_buckets = tf.feature_column.bucketized_column(age, boundaries=[20,30,40,50,60,70,80])

# %% [markdown]
# ### Putting them together

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,assigned_group, age_buckets]

# %% [markdown]
# ### Train Test Split

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
# Number_pregnant          768 non-null float64
# Glucose_concentration    768 non-null float64
# Blood_pressure           768 non-null float64
# Triceps                  768 non-null float64
# Insulin                  768 non-null float64
# BMI                      768 non-null float64
# Pedigree                 768 non-null float64
# Age                      768 non-null int64
# Class                    768 non-null int64
# Group                    768 non-null object
# dtypes: float64(7), int64(2), object(1)
# memory usage: 60.1+ KB

# %%
x_data = diabetes.drop('Class',axis=1)

# %%
labels = diabetes['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,labels,test_size=0.33, random_state=101)

# %%
X_train.head()
# Out:
#      Number_pregnant  Glucose_concentration  Blood_pressure   Triceps  \
# 218         0.294118               0.427136        0.606557  0.222222
# 83          0.000000               0.507538        0.532787  0.282828
# 176         0.352941               0.427136        0.639344  0.000000
# 53          0.470588               0.884422        0.737705  0.343434
# 117         0.294118               0.391960        0.393443  0.000000
#
#      Insulin       BMI  Pedigree  Age Group
# 218  0.00000  0.432191  0.489325   32     A
# 83   0.00000  0.366617  0.067891   22     A
# 176  0.00000  0.464978  0.129804   42     B
# 53   0.35461  0.502235  0.166097   58     C
# 117  0.00000  0.502235  0.245944   25     D

# %% [markdown]
# ### Input Function

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %% [markdown]
# ### Creating the Model

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\HARSHS~1\AppData\Local\Temp\tmpsktd3fyy
# INFO:tensorflow:Using config: {'_evaluation_master': '', '_log_step_count_steps': 100, '_is_chief': True, '_master': '', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000001E9313D69E8>, '_save_checkpoints_secs': 600, '_device_fn': None, '_num_ps_replicas': 0, '_keep_checkpoint_max': 5, '_num_worker_replicas': 1, '_save_summary_steps': 100, '_train_distribute': None, '_service': None, '_task_type': 'worker', '_task_id': 0, '_save_checkpoints_steps': None, '_tf_random_seed': None, '_global_id_in_cluster': 0, '_keep_checkpoint_every_n_hours': 10000, '_session_config': None, '_model_dir': 'C:\\Users\\HARSHS~1\\AppData\\Local\\Temp\\tmpsktd3fyy'}

# %%
model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\HARSHS~1\AppData\Local\Temp\tmpsktd3fyy\model.ckpt.
# INFO:tensorflow:loss = 6.931472, step = 1
# INFO:tensorflow:global_step/sec: 236.487
# INFO:tensorflow:loss = 8.044296, step = 101 (0.427 sec)
# INFO:tensorflow:global_step/sec: 384.166
# INFO:tensorflow:loss = 6.1427712, step = 201 (0.261 sec)
# INFO:tensorflow:global_step/sec: 363.287
# INFO:tensorflow:loss = 5.1692243, step = 301 (0.272 sec)
# INFO:tensorflow:global_step/sec: 371.359
# INFO:tensorflow:loss = 5.2222776, step = 401 (0.269 sec)
# INFO:tensorflow:global_step/sec: 364.61
# INFO:tensorflow:loss = 5.3027945, step = 501 (0.274 sec)
# INFO:tensorflow:global_step/sec: 369.989
# INFO:tensorflow:loss = 5.559707, step = 601 (0.275 sec)
# INFO:tensorflow:global_step/sec: 376.12
# INFO:tensorflow:loss = 6.4307947, step = 701 (0.261 sec)
# INFO:tensorflow:global_step/sec: 364.607
# INFO:tensorflow:loss = 6.6728096, step = 801 (0.274 sec)
# INFO:tensorflow:global_step/sec: 360.674
# INFO:tensorflow:loss = 5.600517, step = 901 (0.280 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\HARSHS~1\AppData\Local\Temp\tmpsktd3fyy\model.ckpt.
# INFO:tensorflow:Loss for final step: 6.5167007.

# %%
# Useful link ofr your own data
# https://stackoverflow.com/questions/44664285/what-are-the-contraints-for-tensorflow-scope-names

# %% [markdown]
# ## Evaluation

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-18-14:44:19
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\HARSHS~1\AppData\Local\Temp\tmpsktd3fyy\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-18-14:44:20
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.72047246, accuracy_baseline = 0.65748036, auc = 0.78831995, auc_precision_recall = 0.63027114, average_loss = 0.5324542, global_step = 1000, label/mean = 0.34251967, loss = 5.201668, precision = 0.59302324, prediction/mean = 0.37869406, recall = 0.5862069
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: C:\Users\HARSHS~1\AppData\Local\Temp\tmpsktd3fyy\model.ckpt-1000

# %%
results
# Out:
# {'accuracy': 0.72047246,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.78831995,
#  'auc_precision_recall': 0.63027114,
#  'average_loss': 0.5324542,
#  'global_step': 1000,
#  'label/mean': 0.34251967,
#  'loss': 5.201668,
#  'precision': 0.59302324,
#  'prediction/mean': 0.37869406,
#  'recall': 0.5862069}

# %% [markdown]
# ## Predictions

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
# Predictions is a generator! 
predictions = model.predict(pred_input_func)

# %%
list(predictions)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\HARSHS~1\AppData\Local\Temp\tmpsktd3fyy\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.54496545], dtype=float32),
#   'logits': array([0.18034887], dtype=float32),
#   'probabilities': array([0.45503464, 0.54496545], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6533137], dtype=float32),
#   'logits': array([0.6336372], dtype=float32),
#   'probabilities': array([0.34668627, 0.6533137 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4017173], dtype=float32),
#   'logits': array([-0.39831477], dtype=float32),
#   'probabilities': array([0.5982827 , 0.40171728], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.331794], dtype=float32),
#   'logits': array([-0.7000823], dtype=float32),
#   'probabilities': array([0.66820604, 0.331794  ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14906172], dtype=float32),
#   'logits': array([-1.7419791], dtype=float32),
#   'probabilities': array([0.85093826, 0.14906172], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7064822], dtype=float32),
#   'logits': array([0.8783593], dtype=float32),
#   'probabilities': array([0.2935179, 0.7064822], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6181919], dtype=float32),
#   'logits': array([0.48188066], dtype=float32),
#   'probabilities': array([0.38180816, 0.6181919 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34388706], dtype=float32),
#   'logits': array([-0.6460196], dtype=float32),
#   'probabilities': array([0.6561129, 0.3438871], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24049331], dtype=float32),
#   'logits': array([-1.1499768], dtype=float32),
#   'probabilities': array([0.7595067 , 0.24049331], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25545168], dtype=float32),
#   'logits': array([-1.0697445], dtype=float32),
#   'probabilities': array([0.7445483 , 0.25545168], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13161981], dtype=float32),
#   'logits': array([-1.8867121], dtype=float32),
#   'probabilities': array([0.8683802 , 0.13161981], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15900235], dtype=float32),
#   'logits': array([-1.6656699], dtype=float32),
#   'probabilities': array([0.84099764, 0.15900235], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32288662], dtype=float32),
#   'logits': array([-0.7405375], dtype=float32),
#   'probabilities': array([0.67711335, 0.3228866 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5865502], dtype=float32),
#   'logits': array([0.34972215], dtype=float32),
#   'probabilities': array([0.4134498, 0.5865502], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17508481], dtype=float32),
#   'logits': array([-1.5500101], dtype=float32),
#   'probabilities': array([0.8249152 , 0.17508481], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3403024], dtype=float32),
#   'logits': array([-0.66194683], dtype=float32),
#   'probabilities': array([0.6596976, 0.3403024], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38500616], dtype=float32),
#   'logits': array([-0.4683529], dtype=float32),
#   'probabilities': array([0.6149938 , 0.38500613], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12917867], dtype=float32),
#   'logits': array([-1.9082403], dtype=float32),
#   'probabilities': array([0.87082136, 0.12917867], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38714013], dtype=float32),
#   'logits': array([-0.45934963], dtype=float32),
#   'probabilities': array([0.6128599 , 0.38714013], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1419574], dtype=float32),
#   'logits': array([-1.7991267], dtype=float32),
#   'probabilities': array([0.8580426, 0.1419574], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21091446], dtype=float32),
#   'logits': array([-1.3194221], dtype=float32),
#   'probabilities': array([0.7890855 , 0.21091445], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29578894], dtype=float32),
#   'logits': array([-0.86743194], dtype=float32),
#   'probabilities': array([0.70421106, 0.29578894], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6626728], dtype=float32),
#   'logits': array([0.675228], dtype=float32),
#   'probabilities': array([0.3373272, 0.6626728], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22467715], dtype=float32),
#   'logits': array([-1.238615], dtype=float32),
#   'probabilities': array([0.77532285, 0.22467716], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18209414], dtype=float32),
#   'logits': array([-1.5022234], dtype=float32),
#   'probabilities': array([0.8179059 , 0.18209417], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7871608], dtype=float32),
#   'logits': array([1.3078954], dtype=float32),
#   'probabilities': array([0.21283925, 0.7871608 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17862551], dtype=float32),
#   'logits': array([-1.5256877], dtype=float32),
#   'probabilities': array([0.8213745, 0.1786255], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.31869602], dtype=float32),
#   'logits': array([-0.7597709], dtype=float32),
#   'probabilities': array([0.681304, 0.318696], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10294765], dtype=float32),
#   'logits': array([-2.1648936], dtype=float32),
#   'probabilities': array([0.8970523 , 0.10294764], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.59166497], dtype=float32),
#   'logits': array([0.37085247], dtype=float32),
#   'probabilities': array([0.40833506, 0.59166497], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.9483597], dtype=float32),
#   'logits': array([2.910432], dtype=float32),
#   'probabilities': array([0.05164027, 0.9483597 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.44036102], dtype=float32),
#   'logits': array([-0.23969704], dtype=float32),
#   'probabilities': array([0.559639, 0.440361], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32252526], dtype=float32),
#   'logits': array([-0.7421908], dtype=float32),
#   'probabilities': array([0.67747474, 0.32252526], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5707238], dtype=float32),
#   'logits': array([0.2848047], dtype=float32),
#   'probabilities': array([0.42927626, 0.5707238 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24860032], dtype=float32),
#   'logits': array([-1.1060913], dtype=float32),
#   'probabilities': array([0.7513997 , 0.24860032], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38808173], dtype=float32),
#   'logits': array([-0.45538276], dtype=float32),
#   'probabilities': array([0.6119183 , 0.38808173], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.52131593], dtype=float32),
#   'logits': array([0.08531547], dtype=float32),
#   'probabilities': array([0.47868404, 0.52131593], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.65055275], dtype=float32),
#   'logits': array([0.6214696], dtype=float32),
#   'probabilities': array([0.3494473 , 0.65055275], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.768239], dtype=float32),
#   'logits': array([1.1983943], dtype=float32),
#   'probabilities': array([0.231761, 0.768239], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3466383], dtype=float32),
#   'logits': array([-0.6338491], dtype=float32),
#   'probabilities': array([0.65336174, 0.3466383 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17804568], dtype=float32),
#   'logits': array([-1.5296447], dtype=float32),
#   'probabilities': array([0.82195437, 0.17804568], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5611303], dtype=float32),
#   'logits': array([0.24575055], dtype=float32),
#   'probabilities': array([0.4388697, 0.5611303], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15521902], dtype=float32),
#   'logits': array([-1.6942403], dtype=float32),
#   'probabilities': array([0.84478104, 0.15521902], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.54920363], dtype=float32),
#   'logits': array([0.1974535], dtype=float32),
#   'probabilities': array([0.4507964 , 0.54920363], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14052841], dtype=float32),
#   'logits': array([-1.8109081], dtype=float32),
#   'probabilities': array([0.8594716 , 0.14052843], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10682778], dtype=float32),
#   'logits': array([-2.1235614], dtype=float32),
#   'probabilities': array([0.8931722 , 0.10682778], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6268909], dtype=float32),
#   'logits': array([0.5189017], dtype=float32),
#   'probabilities': array([0.37310907, 0.6268909 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18968616], dtype=float32),
#   'logits': array([-1.4520507], dtype=float32),
#   'probabilities': array([0.8103138 , 0.18968616], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20974897], dtype=float32),
#   'logits': array([-1.3264391], dtype=float32),
#   'probabilities': array([0.790251  , 0.20974898], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1171442], dtype=float32),
#   'logits': array([-2.0197563], dtype=float32),
#   'probabilities': array([0.8828558 , 0.11714418], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17578447], dtype=float32),
#   'logits': array([-1.5451734], dtype=float32),
#   'probabilities': array([0.82421553, 0.17578447], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25559238], dtype=float32),
#   'logits': array([-1.0690049], dtype=float32),
#   'probabilities': array([0.7444076 , 0.25559238], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25871015], dtype=float32),
#   'logits': array([-1.0526835], dtype=float32),
#   'probabilities': array([0.74128985, 0.25871015], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3879693], dtype=float32),
#   'logits': array([-0.45585626], dtype=float32),
#   'probabilities': array([0.6120307, 0.3879693], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13245565], dtype=float32),
#   'logits': array([-1.8794188], dtype=float32),
#   'probabilities': array([0.86754435, 0.13245565], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23077819], dtype=float32),
#   'logits': array([-1.2039223], dtype=float32),
#   'probabilities': array([0.7692218 , 0.23077819], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21910624], dtype=float32),
#   'logits': array([-1.2708824], dtype=float32),
#   'probabilities': array([0.7808938 , 0.21910624], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2084789], dtype=float32),
#   'logits': array([-1.3341187], dtype=float32),
#   'probabilities': array([0.79152113, 0.2084789 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.50505203], dtype=float32),
#   'logits': array([0.02020884], dtype=float32),
#   'probabilities': array([0.49494797, 0.50505203], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16449971], dtype=float32),
#   'logits': array([-1.6251218], dtype=float32),
#   'probabilities': array([0.83550024, 0.16449971], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22656657], dtype=float32),
#   'logits': array([-1.2278008], dtype=float32),
#   'probabilities': array([0.77343345, 0.22656657], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.66243744], dtype=float32),
#   'logits': array([0.67417514], dtype=float32),
#   'probabilities': array([0.3375626 , 0.66243744], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6536981], dtype=float32),
#   'logits': array([0.6353345], dtype=float32),
#   'probabilities': array([0.34630197, 0.6536981 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5255691], dtype=float32),
#   'logits': array([0.10236573], dtype=float32),
#   'probabilities': array([0.47443086, 0.5255691 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35822055], dtype=float32),
#   'logits': array([-0.5830959], dtype=float32),
#   'probabilities': array([0.6417794 , 0.35822052], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.51244473], dtype=float32),
#   'logits': array([0.04978931], dtype=float32),
#   'probabilities': array([0.4875552 , 0.51244473], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18240727], dtype=float32),
#   'logits': array([-1.5001223], dtype=float32),
#   'probabilities': array([0.81759274, 0.18240729], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19471659], dtype=float32),
#   'logits': array([-1.4196491], dtype=float32),
#   'probabilities': array([0.80528337, 0.19471659], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.150533], dtype=float32),
#   'logits': array([-1.7304268], dtype=float32),
#   'probabilities': array([0.849467  , 0.15053299], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13084646], dtype=float32),
#   'logits': array([-1.8934952], dtype=float32),
#   'probabilities': array([0.86915356, 0.13084647], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6273609], dtype=float32),
#   'logits': array([0.5209116], dtype=float32),
#   'probabilities': array([0.3726391, 0.6273609], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23514907], dtype=float32),
#   'logits': array([-1.1794612], dtype=float32),
#   'probabilities': array([0.7648509 , 0.23514909], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.456151], dtype=float32),
#   'logits': array([-0.17584765], dtype=float32),
#   'probabilities': array([0.54384893, 0.45615098], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.60402507], dtype=float32),
#   'logits': array([0.42226493], dtype=float32),
#   'probabilities': array([0.3959749 , 0.60402507], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.28198552], dtype=float32),
#   'logits': array([-0.934634], dtype=float32),
#   'probabilities': array([0.7180145 , 0.28198552], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6607494], dtype=float32),
#   'logits': array([0.6666355], dtype=float32),
#   'probabilities': array([0.3392506, 0.6607494], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12821974], dtype=float32),
#   'logits': array([-1.9167919], dtype=float32),
#   'probabilities': array([0.8717803 , 0.12821974], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6157517], dtype=float32),
#   'logits': array([0.47155488], dtype=float32),
#   'probabilities': array([0.3842483, 0.6157517], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12573315], dtype=float32),
#   'logits': array([-1.9392238], dtype=float32),
#   'probabilities': array([0.87426686, 0.12573317], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5756555], dtype=float32),
#   'logits': array([0.30496395], dtype=float32),
#   'probabilities': array([0.42434445, 0.5756555 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34380928], dtype=float32),
#   'logits': array([-0.64636433], dtype=float32),
#   'probabilities': array([0.6561907, 0.3438093], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16570555], dtype=float32),
#   'logits': array([-1.616374], dtype=float32),
#   'probabilities': array([0.83429444, 0.16570555], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.57434297], dtype=float32),
#   'logits': array([0.29959273], dtype=float32),
#   'probabilities': array([0.42565703, 0.57434297], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6166039], dtype=float32),
#   'logits': array([0.4751581], dtype=float32),
#   'probabilities': array([0.38339612, 0.6166039 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.585217], dtype=float32),
#   'logits': array([0.3442272], dtype=float32),
#   'probabilities': array([0.41478303, 0.585217  ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16571543], dtype=float32),
#   'logits': array([-1.6163025], dtype=float32),
#   'probabilities': array([0.8342846 , 0.16571544], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.36697012], dtype=float32),
#   'logits': array([-0.5452373], dtype=float32),
#   'probabilities': array([0.6330299, 0.3669701], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15800792], dtype=float32),
#   'logits': array([-1.6731255], dtype=float32),
#   'probabilities': array([0.8419921 , 0.15800792], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.722568], dtype=float32),
#   'logits': array([0.9572356], dtype=float32),
#   'probabilities': array([0.27743202, 0.722568  ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.82966423], dtype=float32),
#   'logits': array([1.5832493], dtype=float32),
#   'probabilities': array([0.1703358 , 0.82966423], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.64197934], dtype=float32),
#   'logits': array([0.58396554], dtype=float32),
#   'probabilities': array([0.3580206 , 0.64197934], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2198345], dtype=float32),
#   'logits': array([-1.266631], dtype=float32),
#   'probabilities': array([0.7801655 , 0.21983452], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.45570913], dtype=float32),
#   'logits': array([-0.17762893], dtype=float32),
#   'probabilities': array([0.54429084, 0.45570916], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.40304887], dtype=float32),
#   'logits': array([-0.39277732], dtype=float32),
#   'probabilities': array([0.5969511, 0.4030489], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4637955], dtype=float32),
#   'logits': array([-0.14507186], dtype=float32),
#   'probabilities': array([0.53620446, 0.46379548], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3673035], dtype=float32),
#   'logits': array([-0.54380244], dtype=float32),
#   'probabilities': array([0.6326965, 0.3673035], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.45031884], dtype=float32),
#   'logits': array([-0.19938254], dtype=float32),
#   'probabilities': array([0.5496811, 0.4503188], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15928097], dtype=float32),
#   'logits': array([-1.6635878], dtype=float32),
#   'probabilities': array([0.84071904, 0.15928096], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.58230484], dtype=float32),
#   'logits': array([0.33224213], dtype=float32),
#   'probabilities': array([0.4176952 , 0.58230484], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.58641714], dtype=float32),
#   'logits': array([0.34917355], dtype=float32),
#   'probabilities': array([0.41358283, 0.58641714], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2588833], dtype=float32),
#   'logits': array([-1.0517807], dtype=float32),
#   'probabilities': array([0.7411167, 0.2588833], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18235135], dtype=float32),
#   'logits': array([-1.5004973], dtype=float32),
#   'probabilities': array([0.81764865, 0.18235135], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1710853], dtype=float32),
#   'logits': array([-1.577955], dtype=float32),
#   'probabilities': array([0.82891476, 0.17108531], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2849566], dtype=float32),
#   'logits': array([-0.92000645], dtype=float32),
#   'probabilities': array([0.7150434 , 0.28495657], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.39670622], dtype=float32),
#   'logits': array([-0.41920817], dtype=float32),
#   'probabilities': array([0.6032938 , 0.39670622], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13823831], dtype=float32),
#   'logits': array([-1.8299997], dtype=float32),
#   'probabilities': array([0.8617617 , 0.13823831], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34549037], dtype=float32),
#   'logits': array([-0.6389215], dtype=float32),
#   'probabilities': array([0.65450966, 0.3454904 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23781547], dtype=float32),
#   'logits': array([-1.1646937], dtype=float32),
#   'probabilities': array([0.76218456, 0.23781547], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10100879], dtype=float32),
#   'logits': array([-2.1860657], dtype=float32),
#   'probabilities': array([0.89899117, 0.10100879], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12508082], dtype=float32),
#   'logits': array([-1.9451715], dtype=float32),
#   'probabilities': array([0.8749192 , 0.12508081], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.76109123], dtype=float32),
#   'logits': array([1.1586714], dtype=float32),
#   'probabilities': array([0.2389088 , 0.76109123], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17470871], dtype=float32),
#   'logits': array([-1.5526164], dtype=float32),
#   'probabilities': array([0.8252913, 0.1747087], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13237667], dtype=float32),
#   'logits': array([-1.8801062], dtype=float32),
#   'probabilities': array([0.86762327, 0.13237667], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14412467], dtype=float32),
#   'logits': array([-1.781446], dtype=float32),
#   'probabilities': array([0.8558754 , 0.14412469], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5132043], dtype=float32),
#   'logits': array([0.05282938], dtype=float32),
#   'probabilities': array([0.48679572, 0.5132043 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4819322], dtype=float32),
#   'logits': array([-0.07230282], dtype=float32),
#   'probabilities': array([0.51806784, 0.48193216], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23335515], dtype=float32),
#   'logits': array([-1.1894622], dtype=float32),
#   'probabilities': array([0.76664484, 0.23335512], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.46591637], dtype=float32),
#   'logits': array([-0.13654637], dtype=float32),
#   'probabilities': array([0.53408366, 0.46591634], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18386732], dtype=float32),
#   'logits': array([-1.4903625], dtype=float32),
#   'probabilities': array([0.81613266, 0.18386732], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23575857], dtype=float32),
#   'logits': array([-1.1760755], dtype=float32),
#   'probabilities': array([0.7642414 , 0.23575856], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.51786095], dtype=float32),
#   'logits': array([0.07147431], dtype=float32),
#   'probabilities': array([0.482139  , 0.51786095], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.50005007], dtype=float32),
#   'logits': array([0.00020015], dtype=float32),
#   'probabilities': array([0.49995   , 0.50005007], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14424735], dtype=float32),
#   'logits': array([-1.7804518], dtype=float32),
#   'probabilities': array([0.85575265, 0.14424737], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.42583534], dtype=float32),
#   'logits': array([-0.2988634], dtype=float32),
#   'probabilities': array([0.5741646 , 0.42583534], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.69321924], dtype=float32),
#   'logits': array([0.8152131], dtype=float32),
#   'probabilities': array([0.30678073, 0.69321924], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5659583], dtype=float32),
#   'logits': array([0.2653799], dtype=float32),
#   'probabilities': array([0.43404168, 0.5659583 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41332266], dtype=float32),
#   'logits': array([-0.3502465], dtype=float32),
#   'probabilities': array([0.5866774 , 0.41332266], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.60729605], dtype=float32),
#   'logits': array([0.43596017], dtype=float32),
#   'probabilities': array([0.392704  , 0.60729605], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23228115], dtype=float32),
#   'logits': array([-1.1954751], dtype=float32),
#   'probabilities': array([0.76771885, 0.23228115], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19641271], dtype=float32),
#   'logits': array([-1.4088677], dtype=float32),
#   'probabilities': array([0.8035873 , 0.19641271], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13546158], dtype=float32),
#   'logits': array([-1.8535076], dtype=float32),
#   'probabilities': array([0.86453843, 0.13546158], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27782083], dtype=float32),
#   'logits': array([-0.9552969], dtype=float32),
#   'probabilities': array([0.7221792 , 0.27782083], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5065613], dtype=float32),
#   'logits': array([0.02624655], dtype=float32),
#   'probabilities': array([0.49343878, 0.5065613 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6973402], dtype=float32),
#   'logits': array([0.8346641], dtype=float32),
#   'probabilities': array([0.30265975, 0.6973402 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22776489], dtype=float32),
#   'logits': array([-1.2209752], dtype=float32),
#   'probabilities': array([0.77223516, 0.22776489], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16708496], dtype=float32),
#   'logits': array([-1.6064292], dtype=float32),
#   'probabilities': array([0.832915  , 0.16708496], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.43523076], dtype=float32),
#   'logits': array([-0.26054078], dtype=float32),
#   'probabilities': array([0.56476927, 0.4352308 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22639757], dtype=float32),
#   'logits': array([-1.2287655], dtype=float32),
#   'probabilities': array([0.7736024 , 0.22639757], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14197463], dtype=float32),
#   'logits': array([-1.7989852], dtype=float32),
#   'probabilities': array([0.8580254 , 0.14197464], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18793306], dtype=float32),
#   'logits': array([-1.4634969], dtype=float32),
#   'probabilities': array([0.812067  , 0.18793307], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12686895], dtype=float32),
#   'logits': array([-1.928931], dtype=float32),
#   'probabilities': array([0.87313104, 0.12686895], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38978612], dtype=float32),
#   'logits': array([-0.44821137], dtype=float32),
#   'probabilities': array([0.6102139, 0.3897861], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7928679], dtype=float32),
#   'logits': array([1.3422997], dtype=float32),
#   'probabilities': array([0.20713215, 0.7928679 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.78335166], dtype=float32),
#   'logits': array([1.2853062], dtype=float32),
#   'probabilities': array([0.21664834, 0.78335166], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5525897], dtype=float32),
#   'logits': array([0.2111398], dtype=float32),
#   'probabilities': array([0.44741026, 0.5525897 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.51649976], dtype=float32),
#   'logits': array([0.06602299], dtype=float32),
#   'probabilities': array([0.48350027, 0.51649976], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.59631145], dtype=float32),
#   'logits': array([0.39011955], dtype=float32),
#   'probabilities': array([0.40368852, 0.59631145], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11318212], dtype=float32),
#   'logits': array([-2.0586414], dtype=float32),
#   'probabilities': array([0.8868179 , 0.11318211], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5638579], dtype=float32),
#   'logits': array([0.25683415], dtype=float32),
#   'probabilities': array([0.43614212, 0.5638579 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7800988], dtype=float32),
#   'logits': array([1.2662423], dtype=float32),
#   'probabilities': array([0.21990119, 0.7800988 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.42567384], dtype=float32),
#   'logits': array([-0.29952407], dtype=float32),
#   'probabilities': array([0.57432616, 0.4256738 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2749727], dtype=float32),
#   'logits': array([-0.9695374], dtype=float32),
#   'probabilities': array([0.7250273 , 0.27497274], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.36790454], dtype=float32),
#   'logits': array([-0.54121685], dtype=float32),
#   'probabilities': array([0.63209546, 0.36790457], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6051808], dtype=float32),
#   'logits': array([0.42709935], dtype=float32),
#   'probabilities': array([0.39481917, 0.6051808 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2310273], dtype=float32),
#   'logits': array([-1.2025195], dtype=float32),
#   'probabilities': array([0.7689727, 0.2310273], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6637733], dtype=float32),
#   'logits': array([0.68015504], dtype=float32),
#   'probabilities': array([0.3362267, 0.6637733], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.42504537], dtype=float32),
#   'logits': array([-0.30209517], dtype=float32),
#   'probabilities': array([0.5749546, 0.4250454], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4380979], dtype=float32),
#   'logits': array([-0.24888527], dtype=float32),
#   'probabilities': array([0.5619021, 0.4380979], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16333847], dtype=float32),
#   'logits': array([-1.633595], dtype=float32),
#   'probabilities': array([0.8366616, 0.1633385], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19361222], dtype=float32),
#   'logits': array([-1.4267075], dtype=float32),
#   'probabilities': array([0.8063878 , 0.19361222], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18851511], dtype=float32),
#   'logits': array([-1.4596876], dtype=float32),
#   'probabilities': array([0.8114849 , 0.18851511], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.44225982], dtype=float32),
#   'logits': array([-0.2319957], dtype=float32),
#   'probabilities': array([0.55774015, 0.44225982], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14691646], dtype=float32),
#   'logits': array([-1.7589934], dtype=float32),
#   'probabilities': array([0.85308355, 0.14691645], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7333727], dtype=float32),
#   'logits': array([1.0118022], dtype=float32),
#   'probabilities': array([0.2666273, 0.7333727], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20248522], dtype=float32),
#   'logits': array([-1.3708334], dtype=float32),
#   'probabilities': array([0.79751474, 0.20248523], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5225166], dtype=float32),
#   'logits': array([0.09012735], dtype=float32),
#   'probabilities': array([0.4774834, 0.5225166], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14912008], dtype=float32),
#   'logits': array([-1.7415192], dtype=float32),
#   'probabilities': array([0.8508799 , 0.14912008], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.69137764], dtype=float32),
#   'logits': array([0.8065678], dtype=float32),
#   'probabilities': array([0.30862236, 0.69137764], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3282137], dtype=float32),
#   'logits': array([-0.7162754], dtype=float32),
#   'probabilities': array([0.6717863, 0.3282137], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19890043], dtype=float32),
#   'logits': array([-1.393181], dtype=float32),
#   'probabilities': array([0.8010996 , 0.19890043], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.36727515], dtype=float32),
#   'logits': array([-0.5439243], dtype=float32),
#   'probabilities': array([0.6327249 , 0.36727518], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3455112], dtype=float32),
#   'logits': array([-0.63882947], dtype=float32),
#   'probabilities': array([0.6544888 , 0.34551117], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1657937], dtype=float32),
#   'logits': array([-1.6157365], dtype=float32),
#   'probabilities': array([0.8342063 , 0.16579369], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.73166], dtype=float32),
#   'logits': array([1.0030613], dtype=float32),
#   'probabilities': array([0.26833996, 0.73166   ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20265862], dtype=float32),
#   'logits': array([-1.36976], dtype=float32),
#   'probabilities': array([0.7973414 , 0.20265862], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17317493], dtype=float32),
#   'logits': array([-1.563291], dtype=float32),
#   'probabilities': array([0.826825 , 0.1731749], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.28340447], dtype=float32),
#   'logits': array([-0.9276365], dtype=float32),
#   'probabilities': array([0.71659553, 0.28340447], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.44440007], dtype=float32),
#   'logits': array([-0.22332329], dtype=float32),
#   'probabilities': array([0.5555999 , 0.44440007], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.277994], dtype=float32),
#   'logits': array([-0.95443386], dtype=float32),
#   'probabilities': array([0.722006  , 0.27799404], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11959528], dtype=float32),
#   'logits': array([-1.9962683], dtype=float32),
#   'probabilities': array([0.8804047 , 0.11959529], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8467557], dtype=float32),
#   'logits': array([1.7093787], dtype=float32),
#   'probabilities': array([0.15324432, 0.8467557 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.68675286], dtype=float32),
#   'logits': array([0.78498197], dtype=float32),
#   'probabilities': array([0.31324717, 0.68675286], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5401282], dtype=float32),
#   'logits': array([0.16085863], dtype=float32),
#   'probabilities': array([0.45987183, 0.5401282 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7432216], dtype=float32),
#   'logits': array([1.0627806], dtype=float32),
#   'probabilities': array([0.25677845, 0.7432216 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1127233], dtype=float32),
#   'logits': array([-2.0632207], dtype=float32),
#   'probabilities': array([0.88727665, 0.1127233 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14201869], dtype=float32),
#   'logits': array([-1.7986237], dtype=float32),
#   'probabilities': array([0.8579813 , 0.14201869], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20925972], dtype=float32),
#   'logits': array([-1.3293934], dtype=float32),
#   'probabilities': array([0.7907403 , 0.20925973], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.33841127], dtype=float32),
#   'logits': array([-0.67038214], dtype=float32),
#   'probabilities': array([0.6615887 , 0.33841127], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.36934552], dtype=float32),
#   'logits': array([-0.53502566], dtype=float32),
#   'probabilities': array([0.6306545 , 0.36934552], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5804885], dtype=float32),
#   'logits': array([0.32477915], dtype=float32),
#   'probabilities': array([0.41951147, 0.5804885 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.57982624], dtype=float32),
#   'logits': array([0.3220601], dtype=float32),
#   'probabilities': array([0.42017376, 0.57982624], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.40264958], dtype=float32),
#   'logits': array([-0.39443737], dtype=float32),
#   'probabilities': array([0.5973505 , 0.40264955], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3792371], dtype=float32),
#   'logits': array([-0.49278772], dtype=float32),
#   'probabilities': array([0.62076294, 0.3792371 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3625885], dtype=float32),
#   'logits': array([-0.5641469], dtype=float32),
#   'probabilities': array([0.6374115 , 0.36258847], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18880665], dtype=float32),
#   'logits': array([-1.4577829], dtype=float32),
#   'probabilities': array([0.81119335, 0.18880667], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6336512], dtype=float32),
#   'logits': array([0.54791284], dtype=float32),
#   'probabilities': array([0.36634877, 0.6336512 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12912792], dtype=float32),
#   'logits': array([-1.9086916], dtype=float32),
#   'probabilities': array([0.8708721, 0.1291279], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25861254], dtype=float32),
#   'logits': array([-1.0531924], dtype=float32),
#   'probabilities': array([0.7413875 , 0.25861257], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5623557], dtype=float32),
#   'logits': array([0.25072813], dtype=float32),
#   'probabilities': array([0.4376443, 0.5623557], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.36203402], dtype=float32),
#   'logits': array([-0.56654674], dtype=float32),
#   'probabilities': array([0.637966  , 0.36203402], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1969141], dtype=float32),
#   'logits': array([-1.405694], dtype=float32),
#   'probabilities': array([0.80308586, 0.1969141 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2776259], dtype=float32),
#   'logits': array([-0.95626867], dtype=float32),
#   'probabilities': array([0.7223741, 0.2776259], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2619369], dtype=float32),
#   'logits': array([-1.0359257], dtype=float32),
#   'probabilities': array([0.7380631 , 0.26193687], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13843423], dtype=float32),
#   'logits': array([-1.828356], dtype=float32),
#   'probabilities': array([0.8615658 , 0.13843423], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18647498], dtype=float32),
#   'logits': array([-1.4730797], dtype=float32),
#   'probabilities': array([0.813525  , 0.18647496], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5900097], dtype=float32),
#   'logits': array([0.36400545], dtype=float32),
#   'probabilities': array([0.4099903, 0.5900097], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6907484], dtype=float32),
#   'logits': array([0.80362034], dtype=float32),
#   'probabilities': array([0.30925164, 0.6907484 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.65530103], dtype=float32),
#   'logits': array([0.6424233], dtype=float32),
#   'probabilities': array([0.34469894, 0.65530103], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.70643646], dtype=float32),
#   'logits': array([0.87813914], dtype=float32),
#   'probabilities': array([0.29356354, 0.70643646], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.489155], dtype=float32),
#   'logits': array([-0.04338682], dtype=float32),
#   'probabilities': array([0.510845, 0.489155], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.30935133], dtype=float32),
#   'logits': array([-0.8031537], dtype=float32),
#   'probabilities': array([0.6906487 , 0.30935133], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.52942216], dtype=float32),
#   'logits': array([0.11782467], dtype=float32),
#   'probabilities': array([0.4705779 , 0.52942216], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17089565], dtype=float32),
#   'logits': array([-1.5792929], dtype=float32),
#   'probabilities': array([0.8291044 , 0.17089565], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1494463], dtype=float32),
#   'logits': array([-1.7389505], dtype=float32),
#   'probabilities': array([0.8505537, 0.1494463], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17754194], dtype=float32),
#   'logits': array([-1.5330906], dtype=float32),
#   'probabilities': array([0.822458  , 0.17754194], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5109182], dtype=float32),
#   'logits': array([0.04367971], dtype=float32),
#   'probabilities': array([0.4890818, 0.5109182], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.05620515], dtype=float32),
#   'logits': array([-2.8209004], dtype=float32),
#   'probabilities': array([0.94379485, 0.05620515], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27343693], dtype=float32),
#   'logits': array([-0.9772542], dtype=float32),
#   'probabilities': array([0.7265631 , 0.27343696], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1714623], dtype=float32),
#   'logits': array([-1.5752989], dtype=float32),
#   'probabilities': array([0.8285377, 0.1714623], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27904734], dtype=float32),
#   'logits': array([-0.94919205], dtype=float32),
#   'probabilities': array([0.7209527 , 0.27904734], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22709727], dtype=float32),
#   'logits': array([-1.2247747], dtype=float32),
#   'probabilities': array([0.77290267, 0.22709727], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27909508], dtype=float32),
#   'logits': array([-0.9489547], dtype=float32),
#   'probabilities': array([0.7209049 , 0.27909508], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.77835023], dtype=float32),
#   'logits': array([1.256078], dtype=float32),
#   'probabilities': array([0.22164978, 0.77835023], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17942193], dtype=float32),
#   'logits': array([-1.5202689], dtype=float32),
#   'probabilities': array([0.8205781 , 0.17942193], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12334518], dtype=float32),
#   'logits': array([-1.9611266], dtype=float32),
#   'probabilities': array([0.8766548 , 0.12334517], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6001321], dtype=float32),
#   'logits': array([0.40601563], dtype=float32),
#   'probabilities': array([0.3998679, 0.6001321], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.50250095], dtype=float32),
#   'logits': array([0.01000381], dtype=float32),
#   'probabilities': array([0.4974991 , 0.50250095], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8510153], dtype=float32),
#   'logits': array([1.7425869], dtype=float32),
#   'probabilities': array([0.14898466, 0.8510153 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6576595], dtype=float32),
#   'logits': array([0.65288126], dtype=float32),
#   'probabilities': array([0.34234056, 0.6576595 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12746856], dtype=float32),
#   'logits': array([-1.923529], dtype=float32),
#   'probabilities': array([0.8725314 , 0.12746854], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6577014], dtype=float32),
#   'logits': array([0.65306747], dtype=float32),
#   'probabilities': array([0.34229863, 0.6577014 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.54224414], dtype=float32),
#   'logits': array([0.16938043], dtype=float32),
#   'probabilities': array([0.4577558 , 0.54224414], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.77247286], dtype=float32),
#   'logits': array([1.2223275], dtype=float32),
#   'probabilities': array([0.22752711, 0.77247286], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23365586], dtype=float32),
#   'logits': array([-1.1877819], dtype=float32),
#   'probabilities': array([0.76634413, 0.23365587], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17512695], dtype=float32),
#   'logits': array([-1.5497183], dtype=float32),
#   'probabilities': array([0.82487303, 0.17512697], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5688708], dtype=float32),
#   'logits': array([0.27724528], dtype=float32),
#   'probabilities': array([0.4311293, 0.5688708], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15006383], dtype=float32),
#   'logits': array([-1.7341006], dtype=float32),
#   'probabilities': array([0.8499361 , 0.15006381], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7851507], dtype=float32),
#   'logits': array([1.2959385], dtype=float32),
#   'probabilities': array([0.21484937, 0.7851507 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5176648], dtype=float32),
#   'logits': array([0.07068861], dtype=float32),
#   'probabilities': array([0.48233518, 0.5176648 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17541303], dtype=float32),
#   'logits': array([-1.5477393], dtype=float32),
#   'probabilities': array([0.8245869 , 0.17541301], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.55624855], dtype=float32),
#   'logits': array([0.2259506], dtype=float32),
#   'probabilities': array([0.44375145, 0.55624855], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4828891], dtype=float32),
#   'logits': array([-0.0684706], dtype=float32),
#   'probabilities': array([0.51711094, 0.482889  ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11187302], dtype=float32),
#   'logits': array([-2.0717502], dtype=float32),
#   'probabilities': array([0.88812697, 0.11187303], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.51687753], dtype=float32),
#   'logits': array([0.06753576], dtype=float32),
#   'probabilities': array([0.48312247, 0.51687753], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6113983], dtype=float32),
#   'logits': array([0.45319366], dtype=float32),
#   'probabilities': array([0.3886017, 0.6113983], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7622216], dtype=float32),
#   'logits': array([1.1648982], dtype=float32),
#   'probabilities': array([0.23777841, 0.7622216 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.81933075], dtype=float32),
#   'logits': array([1.5118201], dtype=float32),
#   'probabilities': array([0.18066922, 0.81933075], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.46120125], dtype=float32),
#   'logits': array([-0.15550762], dtype=float32),
#   'probabilities': array([0.53879875, 0.46120122], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15477319], dtype=float32),
#   'logits': array([-1.6976442], dtype=float32),
#   'probabilities': array([0.8452268, 0.1547732], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09030518], dtype=float32),
#   'logits': array([-2.3099144], dtype=float32),
#   'probabilities': array([0.90969485, 0.09030519], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10599353], dtype=float32),
#   'logits': array([-2.132335], dtype=float32),
#   'probabilities': array([0.8940065 , 0.10599353], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26320243], dtype=float32),
#   'logits': array([-1.0293899], dtype=float32),
#   'probabilities': array([0.73679763, 0.26320243], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34454256], dtype=float32),
#   'logits': array([-0.6431159], dtype=float32),
#   'probabilities': array([0.6554575 , 0.34454253], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26263887], dtype=float32),
#   'logits': array([-1.0322978], dtype=float32),
#   'probabilities': array([0.73736113, 0.26263887], dtype=float32)}]

# %% [markdown]
# # DNN Classifier

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\HARSHS~1\AppData\Local\Temp\tmpbawaddbi
# INFO:tensorflow:Using config: {'_evaluation_master': '', '_log_step_count_steps': 100, '_is_chief': True, '_master': '', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000001E9314A0160>, '_save_checkpoints_secs': 600, '_device_fn': None, '_num_ps_replicas': 0, '_keep_checkpoint_max': 5, '_num_worker_replicas': 1, '_save_summary_steps': 100, '_train_distribute': None, '_service': None, '_task_type': 'worker', '_task_id': 0, '_save_checkpoints_steps': None, '_tf_random_seed': None, '_global_id_in_cluster': 0, '_keep_checkpoint_every_n_hours': 10000, '_session_config': None, '_model_dir': 'C:\\Users\\HARSHS~1\\AppData\\Local\\Temp\\tmpbawaddbi'}

# %%
# UH OH! AN ERROR. Check out the video to see why and how to fix.
# https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-cea30273f6d4> in <module>()
#       1 # UH OH! AN ERROR. Check out the video to see why and how to fix.
#       2 # https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py
# ----> 3 dnn_model.train(input_fn=input_func,steps=1000)
#
# F:\Anaconda\envs\deeplearning\lib\site-packages\tensorflow\python\estimator\estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     364
#     365       saving_listeners = _check_listeners_type(saving_listeners)
# --> 366       loss = self._train_model(input_fn, hooks, saving_listeners)
#     367       logging.info('Loss for final step: %s.', loss)
#     368       return self
#
# F:\Anaconda\envs\deeplearning\lib\site-packages\tensorflow\python\estimator\estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1117       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1118     else:
# -> 1119       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1120
#    1121   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# F:\Anaconda\envs\deeplearning\lib\site-packages\tensorflow\python\estimator\estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1130       worker_hooks.extend(input_hooks)
#    1131       estimator_spec = self._call_model_fn(
# -> 1132           features, labels, model_fn_lib.ModeKeys.TRAIN, self.config)
#    1133       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#    1134                                              hooks, global_step_tensor,
#
# F:\Anaconda\envs\deeplearning\lib\site-packages\tensorflow\python\estimator\estimator.py in _call_model_fn(self, features, labels, mode, config)
#    1105
#    1106     logging.info('Calling model_fn.')
# -> 1107     model_fn_results = self._model_fn(features=features, **kwargs)
#    1108     logging.info('Done calling model_fn.')
#    1109
#
# F:\Anaconda\envs\deeplearning\lib\site-packages\tensorflow\python\estimator\canned\dnn.py in _model_fn(features, labels, mode, config)
#     347           dropout=dropout,
#     348           input_layer_partitioner=input_layer_partitioner,
# --> 349           config=config)
#     350
#     351     super(DNNClassifier, self).__init__(
#
# F:\Anaconda\envs\deeplearning\lib\site-packages\tensorflow\python\estimator\canned\dnn.py in _dnn_model_fn(features, labels, mode, head, hidden_units, feature_columns, optimizer, activation_fn, dropout, input_layer_partitioner, config, tpu_estimator_spec)
#     184         dropout=dropout,
#     185         input_layer_partitioner=input_layer_partitioner)
# --> 186     logits = logit_fn(features=features, mode=mode)
#     187
#     188     if tpu_estimator_spec:
#
# F:\Anaconda\envs\deeplearning\lib\site-packages\tensorflow\python\estimator\canned\dnn.py in dnn_logit_fn(features, mode)
#      89         partitioner=input_layer_partitioner):
#      90       net = feature_column_lib.input_layer(
# ---> 91           features=features, feature_columns=feature_columns)
#      92     for layer_id, num_hidden_units in enumerate(hidden_units):
#      93       with variable_scope.variable_scope(
#
# F:\Anaconda\envs\deeplearning\lib\site-packages\tensorflow\python\feature_column\feature_column.py in input_layer(features, feature_columns, weight_collections, trainable, cols_to_vars)
#     275   """
#     276   return _internal_input_layer(features, feature_columns, weight_collections,
# --> 277                                trainable, cols_to_vars)
#     278
#     279
#
# F:\Anaconda\envs\deeplearning\lib\site-packages\tensorflow\python\feature_column\feature_column.py in _internal_input_layer(features, feature_columns, weight_collections, trainable, cols_to_vars, scope)
#     179           'Items of feature_columns must be a _DenseColumn. '
#     180           'You can wrap a categorical column with an '
# --> 181           'embedding_column or indicator_column. Given: {}'.format(column))
#     182   weight_collections = list(weight_collections or [])
#     183   if ops.GraphKeys.GLOBAL_VARIABLES not in weight_collections:
#
# ValueError: Items of feature_columns must be a _DenseColumn. You can wrap a categorical column with an embedding_column or indicator_column. Given: _VocabularyListCategoricalColumn(key='Group', vocabulary_list=('A', 'B', 'C', 'D'), dtype=tf.string, default_value=-1, num_oov_buckets=0)

# %%
embedded_group_column = tf.feature_column.embedding_column(assigned_group, dimension=4)

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,embedded_group_column, age_buckets]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\HARSHS~1\AppData\Local\Temp\tmpf5ta5at9
# INFO:tensorflow:Using config: {'_evaluation_master': '', '_log_step_count_steps': 100, '_is_chief': True, '_master': '', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000001E9316DF978>, '_save_checkpoints_secs': 600, '_device_fn': None, '_num_ps_replicas': 0, '_keep_checkpoint_max': 5, '_num_worker_replicas': 1, '_save_summary_steps': 100, '_train_distribute': None, '_service': None, '_task_type': 'worker', '_task_id': 0, '_save_checkpoints_steps': None, '_tf_random_seed': None, '_global_id_in_cluster': 0, '_keep_checkpoint_every_n_hours': 10000, '_session_config': None, '_model_dir': 'C:\\Users\\HARSHS~1\\AppData\\Local\\Temp\\tmpf5ta5at9'}

# %%
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\HARSHS~1\AppData\Local\Temp\tmpf5ta5at9\model.ckpt.
# INFO:tensorflow:loss = 7.117474, step = 1
# INFO:tensorflow:global_step/sec: 249.737
# INFO:tensorflow:loss = 6.572612, step = 101 (0.405 sec)
# INFO:tensorflow:global_step/sec: 405.938
# INFO:tensorflow:loss = 5.7101727, step = 201 (0.245 sec)
# INFO:tensorflow:global_step/sec: 356.824
# INFO:tensorflow:loss = 9.188353, step = 301 (0.279 sec)
# INFO:tensorflow:global_step/sec: 371.361
# INFO:tensorflow:loss = 6.0857267, step = 401 (0.269 sec)
# INFO:tensorflow:global_step/sec: 374.131
# INFO:tensorflow:loss = 6.046714, step = 501 (0.267 sec)
# INFO:tensorflow:global_step/sec: 381.244
# INFO:tensorflow:loss = 4.819269, step = 601 (0.264 sec)
# INFO:tensorflow:global_step/sec: 371.361
# INFO:tensorflow:loss = 3.2523603, step = 701 (0.268 sec)
# INFO:tensorflow:global_step/sec: 353.054
# INFO:tensorflow:loss = 5.817569, step = 801 (0.282 sec)
# INFO:tensorflow:global_step/sec: 376.945
# INFO:tensorflow:loss = 2.5442314, step = 901 (0.267 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\HARSHS~1\AppData\Local\Temp\tmpf5ta5at9\model.ckpt.
# INFO:tensorflow:Loss for final step: 5.0323834.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-08-18-14:45:20
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\HARSHS~1\AppData\Local\Temp\tmpf5ta5at9\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-08-18-14:45:20
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.72440946, accuracy_baseline = 0.65748036, auc = 0.7916925, auc_precision_recall = 0.615142, average_loss = 0.5442825, global_step = 1000, label/mean = 0.34251967, loss = 5.3172216, precision = 0.5825243, prediction/mean = 0.4330193, recall = 0.6896552
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: C:\Users\HARSHS~1\AppData\Local\Temp\tmpf5ta5at9\model.ckpt-1000
# {'accuracy': 0.72440946,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.7916925,
#  'auc_precision_recall': 0.615142,
#  'average_loss': 0.5442825,
#  'global_step': 1000,
#  'label/mean': 0.34251967,
#  'loss': 5.3172216,
#  'precision': 0.5825243,
#  'prediction/mean': 0.4330193,
#  'recall': 0.6896552}

# %% [markdown]
# # Great Job!
