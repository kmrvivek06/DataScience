# %%
import nltk

# %%
from nltk.corpus import movie_reviews

# %%
documents = [(list(movie_reviews.words(fileid)), category)
            for category in movie_reviews.categories()
            for fileid in movie_reviews.fileids(category)]

# %%
import random

# %%
random.shuffle(documents)

# %%
all_words = nltk.FreqDist(w.lower() for w in movie_reviews.words())

# %%
word_features = list(all_words)[:2500]

# %%
def document_feature(document):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains({})'.format(word)]=word in document
    return features

# %%
print(document_feature(movie_reviews.words('pos/cv957_8737.txt')))
# Out:
# {'contains(jibe)': False, 'contains(dundee)': False, 'contains(nauseatingly)': False, 'contains(sector)': False, 'contains(articles)': False, 'contains(teach)': False, 'contains(vera)': False, 'contains(nicotine)': False, 'contains(weddell)': False, 'contains(romy)': False, 'contains(febre)': False, 'contains(viscously)': False, 'contains(boot)': False, 'contains(perpetuate)': False, 'contains(hitting)': False, 'contains(00s)': False, 'contains(smoking)': False, 'contains(howerd)': False, 'contains(seducer)': False, 'contains(dollah)': False, 'contains(alienating)': False, 'contains(increases)': False, 'contains(unimportant)': False, 'contains(boringly)': False, 'contains(loveliest)': False, 'contains(seventies)': False, 'contains(seamlessly)': False, 'contains(dysart)': False, 'contains(schoolteacher)': False, 'contains(eartha)': False, 'contains(immature)': False, 'contains(littering)': False, 'contains(dismissive)': False, 'contains(not)': True, 'contains(backstabbers)': False, 'c
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
feature_set = [(document_feature(d),c)for (d,c) in documents]

# %%
train_set, test_set = train_test_split(feature_set, test_size = 0.5)

# %%
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
print(nltk.classify.accuracy(classifier,test_set))
# Out:
# 0.669

# %%
classifier.show_most_informative_features()
# Out:
# Most Informative Features
#         contains(wasted) = True              neg : pos    =      6.9 : 1.0
#          contains(fable) = True              pos : neg    =      6.9 : 1.0
#       contains(religion) = True              pos : neg    =      6.5 : 1.0
#        contains(yelling) = True              neg : pos    =      6.5 : 1.0
#  contains(embarrassment) = True              neg : pos    =      6.5 : 1.0
#         contains(seagal) = True              neg : pos    =      6.5 : 1.0
#         contains(debate) = True              pos : neg    =      6.2 : 1.0
#         contains(smooth) = True              pos : neg    =      6.1 : 1.0
#   contains(preposterous) = True              neg : pos    =      5.8 : 1.0
#      contains(innocence) = True              pos : neg    =      5.7 : 1.0
